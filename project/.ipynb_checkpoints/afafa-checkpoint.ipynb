# %%
import pandas as pd
import numpy as np

# Order_Date: 주문한 날짜
# Time: 주문 시간
# Aging: 주문한 이후의 경과 시간
# Customer_Id: 고객의 고유 식별자
# Gender: 고객의 성별
# Device_Type: 주문을 한 장치 유형
# Customer_Login_type: 고객의 로그인 유형
# Product_Category: 제품 카테고리
# Product: 제품
# Sales: 판매액
# Quantity: 주문 수량
# Discount: 할인
# Profit: 이익
# Shipping_Cost: 배송 비용
# Order_Priority: 주문 우선순위
# Payment_method: 결제 방법

customer = pd.read_csv('./datasets/customer.csv')
customer
# Out:
#        Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0      2018-01-02  10:56:33    8.0        37077  Female         Web
# 1      2018-07-24  20:41:37    2.0        59173  Female         Web
# 2      2018-11-08  08:38:49    8.0        41066  Female         Web
# 3      2018-04-18  19:28:06    7.0        50741  Female         Web
# 4      2018-08-13  21:18:39    9.0        53639  Female         Web
# ...           ...       ...    ...          ...     ...         ...
# 51285  2018-02-28  22:59:50    6.0        78489  Female      Mobile
# 51286  2018-02-28  13:19:25    2.0        91941  Female      Mobile
# 51287  2018-02-28  10:25:07    6.0        63313    Male         Web
# 51288  2018-02-28  10:50:08    7.0        86485    Male         Web
# 51289  2018-02-28  11:09:40    5.0        81129    Male         Web
#
#       Customer_Login_type    Product_Category            Product  Sales  \
# 0                  Member  Auto & Accessories  Car Media Players  140.0
# 1                  Member  Auto & Accessories       Car Speakers  211.0
# 2                  Member  Auto & Accessories    Car Body Covers  117.0
# 3                  Member  Auto & Accessories    Car & Bike Care  118.0
# 4                  Member  Auto & Accessories               Tyre  250.0
# ...                   ...                 ...                ...    ...
# 51285              Member    Home & Furniture          Shoe Rack  124.0
# 51286              Member    Home & Furniture          Umbrellas   70.0
# 51287              Member    Home & Furniture    Dinner Crockery  133.0
# 51288              Member    Home & Furniture        Sofa Covers  216.0
# 51289              Member    Home & Furniture         Bed Sheets  211.0
#
#        Quantity  Discount  Profit  Shipping_Cost Order_Priority Payment_method
# 0           1.0       0.3    46.0            4.6         Medium    credit_card
# 1           1.0       0.3   112.0           11.2         Medium    credit_card
# 2           5.0       0.1    31.2            3.1       Critical    credit_card
# 3           1.0       0.3    26.2            2.6           High    credit_card
# 4           1.0       0.3   160.0           16.0       Critical    credit_card
# ...         ...       ...     ...            ...            ...            ...
# 51285       4.0       0.3    19.2            1.9         Medium    money_order
# 51286       5.0       0.2    14.0            1.4         Medium    credit_card
# 51287       1.0       0.3    39.7            4.0         Medium    credit_card
# 51288       1.0       0.2   131.7           13.2         Medium    credit_card
# 51289       5.0       0.3    99.4            9.9         Medium    credit_card
#
# [51290 rows x 16 columns]

# %%
customer.drop(['Time','Aging', 'Product','Discount', 'Profit', 'Shipping_Cost', 'Order_Priority'  ], axis=1, inplace=True)
customer = customer.dropna()
customer.columns = ['Date', 'CustomerID' ,'Gender' ,'in', 'type' ,'category', 'price','Quantity','payment'  ]
customer
# Out:
#              Date  CustomerID  Gender      in    type            category  \
# 0      2018-01-02       37077  Female     Web  Member  Auto & Accessories
# 1      2018-07-24       59173  Female     Web  Member  Auto & Accessories
# 2      2018-11-08       41066  Female     Web  Member  Auto & Accessories
# 3      2018-04-18       50741  Female     Web  Member  Auto & Accessories
# 4      2018-08-13       53639  Female     Web  Member  Auto & Accessories
# ...           ...         ...     ...     ...     ...                 ...
# 51285  2018-02-28       78489  Female  Mobile  Member    Home & Furniture
# 51286  2018-02-28       91941  Female  Mobile  Member    Home & Furniture
# 51287  2018-02-28       63313    Male     Web  Member    Home & Furniture
# 51288  2018-02-28       86485    Male     Web  Member    Home & Furniture
# 51289  2018-02-28       81129    Male     Web  Member    Home & Furniture
#
#        price  Quantity      payment
# 0      140.0       1.0  credit_card
# 1      211.0       1.0  credit_card
# 2      117.0       5.0  credit_card
# 3      118.0       1.0  credit_card
# 4      250.0       1.0  credit_card
# ...      ...       ...          ...
# 51285  124.0       4.0  money_order
# 51286   70.0       5.0  credit_card
# 51287  133.0       1.0  credit_card
# 51288  216.0       1.0  credit_card
# 51289  211.0       5.0  credit_card
#
# [51287 rows x 9 columns]

# %%
import pandas as pd

# 데이터프레임 예시
customer = pd.DataFrame(customer)

# 'Date' 열을 datetime 형식으로 변환
customer['Date'] = pd.to_datetime(customer['Date'])

# 송장번호 최대 날짜 구하기
InvoiceDate_max = customer['Date'].max()

# InvoiceDate 최대 날짜로부터 지난 구매 날짜로 변경하기 (Recency)
customer['Recency'] = (InvoiceDate_max - customer['Date']).dt.days

# 'Date' 열 삭제
customer.drop(columns=['Date'], inplace=True)

# 결과 출력
customer
# Out:
#        CustomerID  Gender      in    type            category  price  \
# 0           37077  Female     Web  Member  Auto & Accessories  140.0
# 1           59173  Female     Web  Member  Auto & Accessories  211.0
# 2           41066  Female     Web  Member  Auto & Accessories  117.0
# 3           50741  Female     Web  Member  Auto & Accessories  118.0
# 4           53639  Female     Web  Member  Auto & Accessories  250.0
# ...           ...     ...     ...     ...                 ...    ...
# 51285       78489  Female  Mobile  Member    Home & Furniture  124.0
# 51286       91941  Female  Mobile  Member    Home & Furniture   70.0
# 51287       63313    Male     Web  Member    Home & Furniture  133.0
# 51288       86485    Male     Web  Member    Home & Furniture  216.0
# 51289       81129    Male     Web  Member    Home & Furniture  211.0
#
#        Quantity      payment  Recency
# 0           1.0  credit_card      362
# 1           1.0  credit_card      159
# 2           5.0  credit_card       52
# 3           1.0  credit_card      256
# 4           1.0  credit_card      139
# ...         ...          ...      ...
# 51285       4.0  money_order      305
# 51286       5.0  credit_card      305
# 51287       1.0  credit_card      305
# 51288       1.0  credit_card      305
# 51289       5.0  credit_card      305
#
# [51287 rows x 9 columns]

# %%
customer['totalprice'] = customer['price'] * customer['Quantity']
# Out:
#        CustomerID  Gender      in    type            category  price  \
# 0           37077  Female     Web  Member  Auto & Accessories  140.0
# 1           59173  Female     Web  Member  Auto & Accessories  211.0
# 2           41066  Female     Web  Member  Auto & Accessories  117.0
# 3           50741  Female     Web  Member  Auto & Accessories  118.0
# 4           53639  Female     Web  Member  Auto & Accessories  250.0
# ...           ...     ...     ...     ...                 ...    ...
# 51285       78489  Female  Mobile  Member    Home & Furniture  124.0
# 51286       91941  Female  Mobile  Member    Home & Furniture   70.0
# 51287       63313    Male     Web  Member    Home & Furniture  133.0
# 51288       86485    Male     Web  Member    Home & Furniture  216.0
# 51289       81129    Male     Web  Member    Home & Furniture  211.0
#
#        Quantity      payment  Recency  totalprice
# 0           1.0  credit_card      362       140.0
# 1           1.0  credit_card      159       211.0
# 2           5.0  credit_card       52       585.0
# 3           1.0  credit_card      256       118.0
# 4           1.0  credit_card      139       250.0
# ...         ...          ...      ...         ...
# 51285       4.0  money_order      305       496.0
# 51286       5.0  credit_card      305       350.0
# 51287       1.0  credit_card      305       133.0
# 51288       1.0  credit_card      305       216.0
# 51289       5.0  credit_card      305      1055.0
#
# [51287 rows x 10 columns]

# %%
rfm = customer[['Recency', 'Quantity', 'totalprice']].copy()

# 새로운 데이터프레임의 열 이름 변경
rfm.columns = ['Recency', 'Frequency', 'Monetary']

rfm
# Out:
#        Recency  Frequency  Monetary
# 0          362        1.0     140.0
# 1          159        1.0     211.0
# 2           52        5.0     585.0
# 3          256        1.0     118.0
# 4          139        1.0     250.0
# ...        ...        ...       ...
# 51285      305        4.0     496.0
# 51286      305        5.0     350.0
# 51287      305        1.0     133.0
# 51288      305        1.0     216.0
# 51289      305        5.0    1055.0
#
# [51287 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
rfm[['Recency', 'Frequency', 'Monetary']] = \
                                    scaler.fit_transform(rfm[['Recency', 'Frequency', 'Monetary']])
# 최근일 수록 숫자가 더 작게 나오기 때문에, 1을 빼준 값으로 점수를 계산한다.
rfm['Recency'] = 1 - rfm['Recency']
rfm
# Out:
#         Recency  Frequency  Monetary
# 0      0.002755       0.00  0.087921
# 1      0.561983       0.00  0.146261
# 2      0.856749       1.00  0.453574
# 3      0.294766       0.00  0.069844
# 4      0.617080       0.00  0.178307
# ...         ...        ...       ...
# 51285  0.159780       0.75  0.380444
# 51286  0.159780       1.00  0.260477
# 51287  0.159780       0.00  0.082169
# 51288  0.159780       0.00  0.150370
# 51289  0.159780       1.00  0.839770
#
# [51287 rows x 3 columns]

# %%
customer['TotalScore'] = rfm['Recency'] + rfm['Frequency'] + rfm['Monetary']
customer
# Out:
#        CustomerID  Gender      in    type            category  price  \
# 0           37077  Female     Web  Member  Auto & Accessories  140.0
# 1           59173  Female     Web  Member  Auto & Accessories  211.0
# 2           41066  Female     Web  Member  Auto & Accessories  117.0
# 3           50741  Female     Web  Member  Auto & Accessories  118.0
# 4           53639  Female     Web  Member  Auto & Accessories  250.0
# ...           ...     ...     ...     ...                 ...    ...
# 51285       78489  Female  Mobile  Member    Home & Furniture  124.0
# 51286       91941  Female  Mobile  Member    Home & Furniture   70.0
# 51287       63313    Male     Web  Member    Home & Furniture  133.0
# 51288       86485    Male     Web  Member    Home & Furniture  216.0
# 51289       81129    Male     Web  Member    Home & Furniture  211.0
#
#        Quantity      payment  Recency  totalprice  TotalScore
# 0           1.0  credit_card      362       140.0    0.090676
# 1           1.0  credit_card      159       211.0    0.708245
# 2           5.0  credit_card       52       585.0    2.310324
# 3           1.0  credit_card      256       118.0    0.364610
# 4           1.0  credit_card      139       250.0    0.795387
# ...         ...          ...      ...         ...         ...
# 51285       4.0  money_order      305       496.0    1.290223
# 51286       5.0  credit_card      305       350.0    1.420256
# 51287       1.0  credit_card      305       133.0    0.241949
# 51288       1.0  credit_card      305       216.0    0.310149
# 51289       5.0  credit_card      305      1055.0    1.999550
#
# [51287 rows x 11 columns]

# %%
import numpy as np

l1, l2, l3, l4 = np.percentile(customer['TotalScore'], [25, 45, 65, 85])
print(l1, l2, l3, l4)
# Out:
# 0.7206154319772009 1.0122676680904812 1.4428601017269127 1.990137990044616

# %%
def get_level(x):
    if x <= l1:
        return 5
    if x > l1 and x <= l2:
        return 4
    if x > l2 and x <= l3:
        return 3
    if x > l3 and x <= l4:
        return 2
    return 1

# %%
customer['Level'] = customer['TotalScore'].apply(get_level)
customer['Level'] = customer['Level'].replace([5, 4, 3, 2, 1], ['Bronze', 'Silver', 'Gold', 'Diamond', 'VIP'])
print(customer['Level'].value_counts())
customer
# Out:
# Level
# Bronze     12822
# Gold       10259
# Silver     10258
# Diamond    10256
# VIP         7692
# Name: count, dtype: int64
#        CustomerID  Gender      in    type            category  price  \
# 0           37077  Female     Web  Member  Auto & Accessories  140.0
# 1           59173  Female     Web  Member  Auto & Accessories  211.0
# 2           41066  Female     Web  Member  Auto & Accessories  117.0
# 3           50741  Female     Web  Member  Auto & Accessories  118.0
# 4           53639  Female     Web  Member  Auto & Accessories  250.0
# ...           ...     ...     ...     ...                 ...    ...
# 51285       78489  Female  Mobile  Member    Home & Furniture  124.0
# 51286       91941  Female  Mobile  Member    Home & Furniture   70.0
# 51287       63313    Male     Web  Member    Home & Furniture  133.0
# 51288       86485    Male     Web  Member    Home & Furniture  216.0
# 51289       81129    Male     Web  Member    Home & Furniture  211.0
#
#        Quantity      payment  Recency  totalprice  TotalScore   Level
# 0           1.0  credit_card      362       140.0    0.090676  Bronze
# 1           1.0  credit_card      159       211.0    0.708245  Bronze
# 2           5.0  credit_card       52       585.0    2.310324     VIP
# 3           1.0  credit_card      256       118.0    0.364610  Bronze
# 4           1.0  credit_card      139       250.0    0.795387  Silver
# ...         ...          ...      ...         ...         ...     ...
# 51285       4.0  money_order      305       496.0    1.290223    Gold
# 51286       5.0  credit_card      305       350.0    1.420256    Gold
# 51287       1.0  credit_card      305       133.0    0.241949  Bronze
# 51288       1.0  credit_card      305       216.0    0.310149  Bronze
# 51289       5.0  credit_card      305      1055.0    1.999550     VIP
#
# [51287 rows x 12 columns]

# %%
import matplotlib.pyplot as plt

# 데이터프레임의 category 열의 값 분포 확인
plt.figure(figsize=(8, 8))
customer['category'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Category Distribution')
plt.axis('equal')
plt.show()

# %%
# category에 따른 totalprice의 합 원그래프로 시각화
plt.figure(figsize=(8, 8))
total_price_by_category = customer.groupby('category')['totalprice'].sum()
total_price_by_category.plot(kind='pie', autopct='%1.1f%%')
plt.title('Total Price by Category')
plt.axis('equal')
plt.show()

# %%
customer['Gender'].value_counts()
# Out:
# Gender
# Male      28135
# Female    23152
# Name: count, dtype: int64

# %%
# category에 따른 totalprice의 합 원그래프로 시각화
plt.figure(figsize=(8, 8))
total_price_by_category = customer.groupby('category')['Gender'].value_counts()
total_price_by_category.plot(kind='pie', autopct='%1.1f%%')
plt.title('Total Price by Category')
plt.axis('equal')
plt.show()
